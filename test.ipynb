# %%
import glob, torch
# Auto-locate the best checkpoint (notebook output input, dataset, or working dir)
ckpts = glob.glob('./translation_hi/best_model_bak.pt', recursive=True)
ckpts += glob.glob('./translation_hi/best_model_bak.pt', recursive=True)
CKPT = ckpts[0] if ckpts else None
print('checkpoint:', CKPT)
assert CKPT is not None, 'No best_model.pt found — add the training notebook output or a dataset'
# Out:
# checkpoint: ./checkpoints_v2/best_model.pt

# %%
# Load the model once; `translate()` is then usable from any cell
import torch, yaml
from scripts.translate import load_model

config = yaml.safe_load(open('configs/translation_kaggle2.yaml'))
tok, model, inference = load_model(config, CKPT, 'cuda' if torch.cuda.is_available() else 'cpu')

def translate(text: str) -> str:
    return inference.generate(text, max_iterations=30).strip()
# Out:
# Added 6 edit tokens to vocabulary.
# New vocabulary size: 250008
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 14172.59it/s]
# XLMRobertaModel LOAD REPORT from: xlm-roberta-base
# Key                       | Status     |  |
# --------------------------+------------+--+-
# lm_head.dense.bias        | UNEXPECTED |  |
# lm_head.layer_norm.bias   | UNEXPECTED |  |
# lm_head.layer_norm.weight | UNEXPECTED |  |
# lm_head.dense.weight      | UNEXPECTED |  |
# lm_head.bias              | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loaded checkpoint [loaded (strict)]

# %%
# Smoke test — both directions
for s in ['The house was ransacked.', 'Where is the train station?', 'principles']:
    print('EN :', s)
    print('HI :', translate(s))
    print()
for s in ['कैसे हो?', 'रेलवे स्टेशन कहाँ है?', 'मैं कल दिल्ली जा रहा हूँ।']:
    print('HI :', s)
    print('EN :', translate(s))
    print()
# Out:
# EN : The house was ransacked.
# HI : The house was ransacked. उन्होंने में का के में ै का और की ीीम कोे में कियाी है कर एक से लिए..।.।.।।।।।।.।।।.।।।
#
# EN : Where is the train station?
# HI : Where is the train station? गया ने सरा है, गईाटन सेल मनांट नेकर की ट्रेन है of is of at d board- at road a was from.," ins has ands ined to,ing the has tod board of land andging ground of on to ground-ing on, as on ofd and stand?
#
# EN : principles
# HI : principles एक "sमट (,,", को) ",",)."""" “""" ' """""", ',", "" and"""" "." “ """." है....."
#
# HI : कैसे हो?
# EN : कैसे हो? ”"" " ”""""""""" She"""",""" and"."" (""." ” ( है""""?"""""""","""" and," ”", ” """ '.""""""""""
#
# HI : रेलवे स्टेशन कहाँ है?
# EN : रेलवे स्टेशन कहाँ है? India, India Indian, India, India,, India,,, ‘,, Indian,,, as was,, ins, India,-, are that with- asss, of across,,,, India, from anding Bengal.t,s,, from, India,, of India,,, the ( to a launch that and to is the area of in
#
# HI : मैं कल दिल्ली जा रहा हूँ।
# EN : मैं कल दिल्ली जा रहा हूँ। I you he should has we you into you" I are them" I." उन्होंने मैंने," उन्होंने ने कहा ‘ है,. मैं कहा कि वह “, "." मुझे,", आप है तुम तुम, ‘ " ” हम फिर नहीं परमैं, "" तो, ""." ”"""""" """"" """"
